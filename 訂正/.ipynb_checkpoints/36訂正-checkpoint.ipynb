# %% [markdown]
# ## 作業:
# 課程範例以 訓練資料集來檢視，先看一下測試資料特性，再把測試資料集和訓練資料集合併，並回答下列問題，
# 目的:讓大家熟悉對應這樣的問題，我們要提取怎樣的函數來進行計算。
#
# * Q1: 觀察測試(test)資料集和訓練(Train)資料集的變數的差異性?
# * Q2: 測試資料集是否有遺失值?
# * Q3: 從合併資料選取一個變數，嘗試去做各種不同遺失值的處理，並透過圖形或數值來做輔助判斷，補值前與後的差異，你覺得以這個變數而言，試著說明每一個方法的差異。

# %%
#把需要的 library import 進來
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display
#讓圖可以在 jupyter notebook顯示
# %matplotlib inline

# %%
#顯示圖形的函數，可不先不用理解，直接用
from IPython.display import display
from IPython.display import display_html
def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
# 把兩個訓練資料集和測試資料集讀進來
df_test = pd.read_csv("Titanic_test.csv")
df_train = pd.read_csv("Titanic_train.csv")
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Q1: 判斷 測試資料集和訓練資料集欄位變數是否有差異性?

# %%
# Q1: 判斷 測試資料集和訓練資料集欄位變數是否有差異性?

print(len(df_test.columns) == len(df_train.columns))
print(df_test.columns)
print(df_train.columns)
print("有差異")
# Out:
# False
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# 有差異

# %% [markdown]
# ## A1 : Test 資料集沒有 'Survived'

# %% [markdown]
# ## Q2: 測試資料集是否有遺失值?

# %%
#可以嘗試用範例的程式
print(df_test.isnull().any()) # any：判斷一個tuple或者list是否全為空
#如果全為空，則返回False；如果不全為空，則返回True。
print("Age、Fare、Cabin有遺失值")
print("總共:", df_test.isnull().any().sum(),"個遺失值")
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked       False
# dtype: bool
# Age、Fare、Cabin有遺失值
# 總共: 3 個遺失值

# %% [markdown]
# ## Q3: 從合併資料選取一個變數，嘗試去做各種不同遺失值的處理，並透過圖形來做輔助判斷，補值前與後的差異，你覺得以這個變數而言，試著說明每一個方法的差異。

# %%
#合併資料
data = df_train.append(df_test)
print(data.isnull().any())
print("總共:", data.isnull().any().sum(),"個遺失值")
# Out:
# PassengerId    False
# Survived        True
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin           True
# Embarked        True
# dtype: bool
# 總共: 5 個遺失值

# %%
# 以 XXX 為例，先看 Cabin  出現值的特性
#-------------------------------
# print(data["Cabin"])
# data["Cabin"]=data["Cabin"].fillna(method= 'pad') 
# print(data["Cabin"])
#-------------------------------
#解答
# 以 Cabin 為例，先看 Cabin  出現值的特性
print(data["Cabin"].value_counts())
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# D                  4
# B96 B98            4
#                   ..
# B11                1
# E68                1
# B3                 1
# D34                1
# D22                1
# Name: Cabin, Length: 186, dtype: int64

# %% [markdown]
# ### cabin 不能隨意補值，須先進一步觀察和處理
# * 方法1:遺失的屬於另一類。
# * 方法2:看 cabin 和其他變數有無關係，可以進行補值。
# * 方法3:遺失比例太高，可以先不放入模型。

# %%
#* 方法1:把遺失值歸於另一類。 
data["Cabin"].head(10)
#填入NoCabin
data["Cabin"] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')
data["Cabin"].unique()
# Out:
# array(['N', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
# 挑整後的 Cabin 觀察遺失的樣態
sns.countplot(data['Cabin'], hue=data['Survived'])
#結論，遺失的死亡率比較高

# %%
#數值計算
data[['Cabin', 'Survived']].groupby(['Cabin'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# NoCabin的比例和 T 較接近，所以把T的數值去填補 NoCabin
# Out:
#   Cabin  Survived
# 3     D  0.757576
# 4     E  0.750000
# 1     B  0.744681
# 5     F  0.615385
# 2     C  0.593220
# 6     G  0.500000
# 0     A  0.466667
# 7     N  0.299854
# 8     T  0.000000
