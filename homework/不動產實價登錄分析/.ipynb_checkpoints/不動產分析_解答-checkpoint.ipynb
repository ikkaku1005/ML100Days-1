# %% [markdown]
# 哈摟，各位資料科學家大家好，我是來自於台北市"頭期款不足"的阿宏，我想買房子很久了，但是不知道要買哪個地方，想先從內政部不動產交易時價登入資料中先了解行情，我現在手邊蒐集了台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)共四份資料，請各位資料科學家幫幫忙分析了。

# %% [markdown]
# # 1.不動產資料檔案讀取並串接

# %% [markdown]
# 資料分散在4個資料，先合併成一個資料方便後續分析，但是我發現有英文欄位跟中文欄位，留下中文刪除英文，並加入新的欄位用以分辨台北市Taipei、新北市New_Taipei、台中市Taichung、高雄市Kaohsiung

# %% [markdown]
# 1. 利用Pandas中的pd.read_csv()分別讀取A_lvr_land_A.csv、B_lvr_land_A.csv、E_lvr_land_A.csv、F_lvr_land_A.csv
# 2. 刪除csv中第二列英文翻譯，The villages and towns urban district,transaction sign,land sector position building sector house number plate,land shifting total area square meter,....
# 3. 生成city欄位其中以地區分類台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)
# 4. 將以上四份資料運用pd.concat()串接

# %%
import pandas as pd

# %%
#1.利用Pandas中的pd.read_csv()分別讀取A_lvr_land_A.csv、B_lvr_land_A.csv、E_lvr_land_A.csv、F_lvr_land_A.csv
df_a = pd.read_csv('A_lvr_land_A.csv')
df_b = pd.read_csv('B_lvr_land_A.csv')
df_e = pd.read_csv('E_lvr_land_A.csv')
df_f = pd.read_csv('F_lvr_land_A.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (3,7,14,15,16,17,18,21,22,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_a.head()
# Out:
#                                     鄉鎮市區              交易標的  \
# 0  The villages and towns urban district  transaction sign
# 1                                    文山區      房地(土地+建物)+車位
# 2                                    文山區         房地(土地+建物)
# 3                                    文山區         房地(土地+建物)
# 4                                    中正區         房地(土地+建物)
#
#                                         土地區段位置建物區段門牌  \
# 0  land sector position building sector house num...
# 1                                臺北市文山區忠順街二段85巷1~30號
# 2                                   臺北市文山區福興路91~120號
# 3                                臺北市文山區木柵路四段121~150號
# 4                                 臺北市中正區和平西路一段31~60號
#
#                              土地移轉總面積平方公尺  \
# 0  land shifting total area square meter
# 1                                  26.97
# 2                                  10.32
# 3                                  39.64
# 4                                   4.26
#
#                                 都市土地使用分區  \
# 0  the use zoning or compiles and checks
# 1                                      住
# 2                                      住
# 3                                     其他
# 4                                      商
#
#                               非都市土地使用分區                非都市土地使用編定  \
# 0  the non-metropolis land use district  non-metropolis land use
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
#
#                             交易年月日                   交易筆棟數            移轉層次  \
# 0  transaction year month and day  transaction pen number  shifting level
# 1                         1090406               土地1建物1車位2              四層
# 2                         1090317               土地1建物1車位0              三層
# 3                         1090418               土地2建物1車位0              六層
# 4                         1090413               土地2建物1車位0              九層
#
#    ...                              單價元平方公尺                車位類別  \
# 0  ...  the unit price (NTD / square meter)  the berth category
# 1  ...                               156583                坡道平面
# 2  ...                               149558                 NaN
# 3  ...                               181472                 NaN
# 4  ...                               299450                 NaN
#
#                             車位移轉總面積(平方公尺)                      車位總價元  \
# 0  berth shifting total area square meter  the berth total price NTD
# 1                                    40.7                          0
# 2                                     0.0                          0
# 3                                     0.0                          0
# 4                                     0.0                          0
#
#                              備註                   編號   主建物面積 附屬建物面積   陽台面積  \
# 0                      the note        serial number     NaN    NaN    NaN
# 1  含增建或未登記建物。;內含獨立產權車位，未包含在棟數內。  RPVOMLMKNHPFFAA18CA  110.91   9.63  11.09
# 2                   含增建或未登記建物。;  RPPPMLMKNHPFFAA67CA   24.58   1.28   2.30
# 3                           NaN  RPSPMLMKNHPFFAA97CA   78.80   4.15   8.76
# 4                   含增建或未登記建物。;  RPPOMLMKNHPFFAA57CA   18.34   0.00   6.45
#
#     電梯
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 32 columns]

# %%
#2.刪除csv中第二列英文翻譯，The villages and towns urban district,transaction sign,land sector position building sector house number plate,land shifting total area square meter,....
#方法一
df_a = df_a.iloc[1:] #從第二列開始取到最後
df_b = df_b.iloc[1:]
df_e = df_e.iloc[1:]
df_f = df_f.iloc[1:]
display(df_a.head())

#方法二         labels = 0 第一列
#df_a = df_a.drop(labels = 0, axis = 0)
#df_a = df_a.drop([0])
#df_a = df_a.drop(0)
# Out:
#   鄉鎮市區          交易標的         土地區段位置建物區段門牌 土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 1  文山區  房地(土地+建物)+車位  臺北市文山區忠順街二段85巷1~30號       26.97        住       NaN
# 2  文山區     房地(土地+建物)     臺北市文山區福興路91~120號       10.32        住       NaN
# 3  文山區     房地(土地+建物)  臺北市文山區木柵路四段121~150號       39.64       其他       NaN
# 4  中正區     房地(土地+建物)   臺北市中正區和平西路一段31~60號        4.26        商       NaN
# 5  文山區     房地(土地+建物)    臺北市文山區樟新街56巷1~30號       44.57        住       NaN
#
#   非都市土地使用編定    交易年月日      交易筆棟數 移轉層次  ... 單價元平方公尺  車位類別 車位移轉總面積(平方公尺) 車位總價元  \
# 1       NaN  1090406  土地1建物1車位2   四層  ...  156583  坡道平面          40.7     0
# 2       NaN  1090317  土地1建物1車位0   三層  ...  149558   NaN           0.0     0
# 3       NaN  1090418  土地2建物1車位0   六層  ...  181472   NaN           0.0     0
# 4       NaN  1090413  土地2建物1車位0   九層  ...  299450   NaN           0.0     0
# 5       NaN  1090328  土地3建物1車位0   四層  ...  147825   NaN           0.0     0
#
#                              備註                   編號   主建物面積 附屬建物面積   陽台面積  \
# 1  含增建或未登記建物。;內含獨立產權車位，未包含在棟數內。  RPVOMLMKNHPFFAA18CA  110.91   9.63  11.09
# 2                   含增建或未登記建物。;  RPPPMLMKNHPFFAA67CA   24.58   1.28   2.30
# 3                           NaN  RPSPMLMKNHPFFAA97CA   78.80   4.15   8.76
# 4                   含增建或未登記建物。;  RPPOMLMKNHPFFAA57CA   18.34   0.00   6.45
# 5                   含增建或未登記建物。;  RPWNMLNKNHPFFAA28CA   98.74   2.26  11.84
#
#     電梯
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
#
# [5 rows x 32 columns]

# %%
#3. 生成city欄位其中以地區分類台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)
#方法一:增加新欄位
df_a['city'] = 'Taipei'
df_b['city'] = 'Taichung'
df_e['city'] = 'Kaohsiung'
df_f['city'] = 'New_Taipei'

#方法二
#df_a.insert(0, "city","Taipei")
#df_b.insert(0, "city","Taichung")
#df_c.insert(0, "city","kaohsiung")
#df_d.insert(0, "city","New_Taipei")

# %%
#4. 將以上四份資料運用pd.concat()串接
#方法一
all_df = pd.concat([df_a, df_b, df_e, df_f],axis=0)
display(all_df)

#重新設定索引 => 因為index沒有接續下去
all_df = all_df.reset_index(drop = True)  #drop("index",axis = 1)
#查看數據大小
print(all_df.shape)
#查看新數據及
print(all_df.describe())
display(all_df)
# Out:
#       鄉鎮市區          交易標的         土地區段位置建物區段門牌 土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 1      文山區  房地(土地+建物)+車位  臺北市文山區忠順街二段85巷1~30號       26.97        住       NaN
# 2      文山區     房地(土地+建物)     臺北市文山區福興路91~120號       10.32        住       NaN
# 3      文山區     房地(土地+建物)  臺北市文山區木柵路四段121~150號       39.64       其他       NaN
# 4      中正區     房地(土地+建物)   臺北市中正區和平西路一段31~60號        4.26        商       NaN
# 5      文山區     房地(土地+建物)    臺北市文山區樟新街56巷1~30號       44.57        住       NaN
# ...    ...           ...                  ...         ...      ...       ...
# 19814  鶯歌區  房地(土地+建物)+車位           國中街91~120號       28.21       其他       NaN
# 19815  三峽區            土地     成福段成福小段331~360地號       762.0      NaN    山坡地保育區
# 19816  鶯歌區  房地(土地+建物)+車位           國中街91~120號       28.21       其他       NaN
# 19817  鶯歌區  房地(土地+建物)+車位          中山路301~330號       19.85       其他       NaN
# 19818  鶯歌區  房地(土地+建物)+車位           國中街91~120號       26.94       其他       NaN
#
#       非都市土地使用編定    交易年月日      交易筆棟數 移轉層次  ...  車位類別 車位移轉總面積(平方公尺)    車位總價元  \
# 1           NaN  1090406  土地1建物1車位2   四層  ...  坡道平面          40.7        0
# 2           NaN  1090317  土地1建物1車位0   三層  ...   NaN           0.0        0
# 3           NaN  1090418  土地2建物1車位0   六層  ...   NaN           0.0        0
# 4           NaN  1090413  土地2建物1車位0   九層  ...   NaN           0.0        0
# 5           NaN  1090328  土地3建物1車位0   四層  ...   NaN           0.0        0
# ...         ...      ...        ...  ...  ...   ...           ...      ...
# 19814       NaN  1080817  土地2建物1車位1  十三層  ...  坡道平面         30.31  1100000
# 19815      農牧用地  1090814  土地2建物0車位0  NaN  ...   NaN           0.0        0
# 19816       NaN  1080831  土地2建物1車位1   四層  ...  坡道平面         30.31  1400000
# 19817       NaN  1090809  土地1建物1車位1   七層  ...  坡道平面         24.14        0
# 19818       NaN  1090225  土地2建物1車位1  十一層  ...  坡道平面         33.05  1250000
#
#                                  備註                   編號   主建物面積 附屬建物面積  \
# 1      含增建或未登記建物。;內含獨立產權車位，未包含在棟數內。  RPVOMLMKNHPFFAA18CA  110.91   9.63
# 2                       含增建或未登記建物。;  RPPPMLMKNHPFFAA67CA   24.58   1.28
# 3                               NaN  RPSPMLMKNHPFFAA97CA   78.80   4.15
# 4                       含增建或未登記建物。;  RPPOMLMKNHPFFAA57CA   18.34   0.00
# 5                       含增建或未登記建物。;  RPWNMLNKNHPFFAA28CA   98.74   2.26
# ...                             ...                  ...     ...    ...
# 19814             預售屋、或土地及建物分次登記案件;  RPXNMLOJRHPFFIF57DA   73.39   2.65
# 19815         親友、員工、共有人或其他特殊關係間之交易;  RPQNMLRLQHPFFIF27DA    0.00   0.00
# 19816             預售屋、或土地及建物分次登記案件;  RPSPMLLLQHPFFIF07DA   73.40   2.64
# 19817                           NaN  RPUOMLRKQHPFFIF67DA   51.72   0.00
# 19818             預售屋、或土地及建物分次登記案件;  RPSOMLSJQHPFFIF47DA   69.20   2.42
#
#         陽台面積   電梯        city
# 1      11.09  NaN      Taipei
# 2       2.30  NaN      Taipei
# 3       8.76  NaN      Taipei
# 4       6.45  NaN      Taipei
# 5      11.84  NaN      Taipei
# ...      ...  ...         ...
# 19814   8.52    有  New_Taipei
# 19815   0.00    無  New_Taipei
# 19816   8.52    有  New_Taipei
# 19817   5.40    有  New_Taipei
# 19818   8.52    有  New_Taipei
#
# [59476 rows x 33 columns]
# (59476, 33)
#               主建物面積        附屬建物面積          陽台面積
# count  59476.000000  59476.000000  59476.000000
# mean      79.128890      5.470561      3.220769
# std      165.318619     10.075095      5.753949
# min        0.000000      0.000000      0.000000
# 25%       32.847500      0.000000      0.000000
# 50%       69.360000      1.470000      0.000000
# 75%       96.432500      8.370000      5.230000
# max    25959.340000    908.560000    176.690000
#       鄉鎮市區          交易標的         土地區段位置建物區段門牌 土地移轉總面積平方公尺 都市土地使用分區 非都市土地使用分區  \
# 0      文山區  房地(土地+建物)+車位  臺北市文山區忠順街二段85巷1~30號       26.97        住       NaN
# 1      文山區     房地(土地+建物)     臺北市文山區福興路91~120號       10.32        住       NaN
# 2      文山區     房地(土地+建物)  臺北市文山區木柵路四段121~150號       39.64       其他       NaN
# 3      中正區     房地(土地+建物)   臺北市中正區和平西路一段31~60號        4.26        商       NaN
# 4      文山區     房地(土地+建物)    臺北市文山區樟新街56巷1~30號       44.57        住       NaN
# ...    ...           ...                  ...         ...      ...       ...
# 59471  鶯歌區  房地(土地+建物)+車位           國中街91~120號       28.21       其他       NaN
# 59472  三峽區            土地     成福段成福小段331~360地號       762.0      NaN    山坡地保育區
# 59473  鶯歌區  房地(土地+建物)+車位           國中街91~120號       28.21       其他       NaN
# 59474  鶯歌區  房地(土地+建物)+車位          中山路301~330號       19.85       其他       NaN
# 59475  鶯歌區  房地(土地+建物)+車位           國中街91~120號       26.94       其他       NaN
#
#       非都市土地使用編定    交易年月日      交易筆棟數 移轉層次  ...  車位類別 車位移轉總面積(平方公尺)    車位總價元  \
# 0           NaN  1090406  土地1建物1車位2   四層  ...  坡道平面          40.7        0
# 1           NaN  1090317  土地1建物1車位0   三層  ...   NaN           0.0        0
# 2           NaN  1090418  土地2建物1車位0   六層  ...   NaN           0.0        0
# 3           NaN  1090413  土地2建物1車位0   九層  ...   NaN           0.0        0
# 4           NaN  1090328  土地3建物1車位0   四層  ...   NaN           0.0        0
# ...         ...      ...        ...  ...  ...   ...           ...      ...
# 59471       NaN  1080817  土地2建物1車位1  十三層  ...  坡道平面         30.31  1100000
# 59472      農牧用地  1090814  土地2建物0車位0  NaN  ...   NaN           0.0        0
# 59473       NaN  1080831  土地2建物1車位1   四層  ...  坡道平面         30.31  1400000
# 59474       NaN  1090809  土地1建物1車位1   七層  ...  坡道平面         24.14        0
# 59475       NaN  1090225  土地2建物1車位1  十一層  ...  坡道平面         33.05  1250000
#
#                                  備註                   編號   主建物面積 附屬建物面積  \
# 0      含增建或未登記建物。;內含獨立產權車位，未包含在棟數內。  RPVOMLMKNHPFFAA18CA  110.91   9.63
# 1                       含增建或未登記建物。;  RPPPMLMKNHPFFAA67CA   24.58   1.28
# 2                               NaN  RPSPMLMKNHPFFAA97CA   78.80   4.15
# 3                       含增建或未登記建物。;  RPPOMLMKNHPFFAA57CA   18.34   0.00
# 4                       含增建或未登記建物。;  RPWNMLNKNHPFFAA28CA   98.74   2.26
# ...                             ...                  ...     ...    ...
# 59471             預售屋、或土地及建物分次登記案件;  RPXNMLOJRHPFFIF57DA   73.39   2.65
# 59472         親友、員工、共有人或其他特殊關係間之交易;  RPQNMLRLQHPFFIF27DA    0.00   0.00
# 59473             預售屋、或土地及建物分次登記案件;  RPSPMLLLQHPFFIF07DA   73.40   2.64
# 59474                           NaN  RPUOMLRKQHPFFIF67DA   51.72   0.00
# 59475             預售屋、或土地及建物分次登記案件;  RPSOMLSJQHPFFIF47DA   69.20   2.42
#
#         陽台面積   電梯        city
# 0      11.09  NaN      Taipei
# 1       2.30  NaN      Taipei
# 2       8.76  NaN      Taipei
# 3       6.45  NaN      Taipei
# 4      11.84  NaN      Taipei
# ...      ...  ...         ...
# 59471   8.52    有  New_Taipei
# 59472   0.00    無  New_Taipei
# 59473   8.52    有  New_Taipei
# 59474   5.40    有  New_Taipei
# 59475   8.52    有  New_Taipei
#
# [59476 rows x 33 columns]

# %% [markdown]
# # 2. 資料清理與切片

# %% [markdown]
# 因為我是想買來住的房子，所以幫忙刪除住宿用途以外的資料，並且限制
# 1. 交易年月日，限制在109年
# 2. 建物現況格局-房，1~5間
# 3. 建物現況格局-廳，1~2廳

# %% [markdown]
# 以下columns_mapping、analysis_columns、columns_type提供給資料科學家配合使用
# 1. 利用.rename()並配合以下columns_mapping，將原中文欄位名稱改為英文方便之後分析
# 2. 取出主要用途(main_use)為'住家用'以及都市土地使用分區(use_zoning)為'住'的資料並針對以下欄位analysis_columns做分析並去除na值
#    (提示:先取完之後再.dropna())
# 3. 觀察欄位資料型態，並利用.astype()搭配以下提供的columns_type做欄位型態轉換
# 4. 做資料切片將<br>
#     新增欄位交易年月日(tx_dt_year)，從交易年月日(tx_dt)萃取出年份<br>
#     1.交易年月日(tx_dt_year)，限制在109年<br>
#     2.建物現況格局-房(room_number)，限制在1到5間<br>
#     3.建物現況格局-廳(hall_number)，限制在1到2廳<br>
#     4.最後運用.reset_index()重新定義索引

# %%
columns_mapping = {'鄉鎮市區':'towns',
'交易標的':'transaction_sign',
'土地區段位置建物區段門牌':'house_number',
'土地移轉總面積平方公尺':'land_area_square_meter', 
'都市土地使用分區':'use_zoning', 
'非都市土地使用分區':'land_use_district',
'非都市土地使用編定':'land_use',
'交易年月日':'tx_dt', 
 '交易筆棟數':'transaction_pen_number', 
 '移轉層次':'shifting_level', 
 '總樓層數':'total_floor_number', 
 '建物型態':'building_state', 
 '主要用途':'main_use', 
 '主要建材':'main_materials',
 '建築完成年月':'complete_date', 
 '建物移轉總面積平方公尺':'building_area_square_meter', 
 '建物現況格局-房':'room_number', 
 '建物現況格局-廳':'hall_number', 
 '建物現況格局-衛':'health_number', 
'建物現況格局-隔間':'compartmented_number', 
 '有無管理組織':'manages', 
 '總價元':'total_price', 
 '單價元平方公尺':'unit_price', 
 '車位類別':'berth_category', 
 '車位移轉總面積(平方公尺)':'berth_area_square_meter',
'車位總價元':'berth_price', 
 '備註':'note', 
 '編號':'serial_number', 
 '主建物面積':'main_building_area', 
 '附屬建物面積':'auxiliary_building_area', 
 '陽台面積':'balcony_area', 
 '電梯':'elevator'
                  }
analysis_columns = ['city','towns','main_use','use_zoning','total_price','building_area_square_meter',
                                     'main_building_area',
                                     'tx_dt','unit_price','room_number','hall_number','health_number']
columns_type = {'total_price': 'int','unit_price':'float','building_area_square_meter':'float',
                                      'main_building_area': 'float',
                                      'room_number': 'int','hall_number': 'int','health_number': 'int'}

# %%
#1. 利用.rename()並配合以下columns_mapping，將原中文欄位名稱改為英文方便之後分析
new_df = all_df.rename(columns=columns_mapping)
new_df
# Out:
#       towns transaction_sign         house_number land_area_square_meter  \
# 0       文山區     房地(土地+建物)+車位  臺北市文山區忠順街二段85巷1~30號                  26.97
# 1       文山區        房地(土地+建物)     臺北市文山區福興路91~120號                  10.32
# 2       文山區        房地(土地+建物)  臺北市文山區木柵路四段121~150號                  39.64
# 3       中正區        房地(土地+建物)   臺北市中正區和平西路一段31~60號                   4.26
# 4       文山區        房地(土地+建物)    臺北市文山區樟新街56巷1~30號                  44.57
# ...     ...              ...                  ...                    ...
# 59471   鶯歌區     房地(土地+建物)+車位           國中街91~120號                  28.21
# 59472   三峽區               土地     成福段成福小段331~360地號                  762.0
# 59473   鶯歌區     房地(土地+建物)+車位           國中街91~120號                  28.21
# 59474   鶯歌區     房地(土地+建物)+車位          中山路301~330號                  19.85
# 59475   鶯歌區     房地(土地+建物)+車位           國中街91~120號                  26.94
#
#       use_zoning land_use_district land_use    tx_dt transaction_pen_number  \
# 0              住               NaN      NaN  1090406              土地1建物1車位2
# 1              住               NaN      NaN  1090317              土地1建物1車位0
# 2             其他               NaN      NaN  1090418              土地2建物1車位0
# 3              商               NaN      NaN  1090413              土地2建物1車位0
# 4              住               NaN      NaN  1090328              土地3建物1車位0
# ...          ...               ...      ...      ...                    ...
# 59471         其他               NaN      NaN  1080817              土地2建物1車位1
# 59472        NaN            山坡地保育區     農牧用地  1090814              土地2建物0車位0
# 59473         其他               NaN      NaN  1080831              土地2建物1車位1
# 59474         其他               NaN      NaN  1090809              土地1建物1車位1
# 59475         其他               NaN      NaN  1090225              土地2建物1車位1
#
#       shifting_level  ... berth_category berth_area_square_meter berth_price  \
# 0                 四層  ...           坡道平面                    40.7           0
# 1                 三層  ...            NaN                     0.0           0
# 2                 六層  ...            NaN                     0.0           0
# 3                 九層  ...            NaN                     0.0           0
# 4                 四層  ...            NaN                     0.0           0
# ...              ...  ...            ...                     ...         ...
# 59471            十三層  ...           坡道平面                   30.31     1100000
# 59472            NaN  ...            NaN                     0.0           0
# 59473             四層  ...           坡道平面                   30.31     1400000
# 59474             七層  ...           坡道平面                   24.14           0
# 59475            十一層  ...           坡道平面                   33.05     1250000
#
#                                note        serial_number main_building_area  \
# 0      含增建或未登記建物。;內含獨立產權車位，未包含在棟數內。  RPVOMLMKNHPFFAA18CA             110.91
# 1                       含增建或未登記建物。;  RPPPMLMKNHPFFAA67CA              24.58
# 2                               NaN  RPSPMLMKNHPFFAA97CA              78.80
# 3                       含增建或未登記建物。;  RPPOMLMKNHPFFAA57CA              18.34
# 4                       含增建或未登記建物。;  RPWNMLNKNHPFFAA28CA              98.74
# ...                             ...                  ...                ...
# 59471             預售屋、或土地及建物分次登記案件;  RPXNMLOJRHPFFIF57DA              73.39
# 59472         親友、員工、共有人或其他特殊關係間之交易;  RPQNMLRLQHPFFIF27DA               0.00
# 59473             預售屋、或土地及建物分次登記案件;  RPSPMLLLQHPFFIF07DA              73.40
# 59474                           NaN  RPUOMLRKQHPFFIF67DA              51.72
# 59475             預售屋、或土地及建物分次登記案件;  RPSOMLSJQHPFFIF47DA              69.20
#
#       auxiliary_building_area balcony_area elevator        city
# 0                        9.63        11.09      NaN      Taipei
# 1                        1.28         2.30      NaN      Taipei
# 2                        4.15         8.76      NaN      Taipei
# 3                        0.00         6.45      NaN      Taipei
# 4                        2.26        11.84      NaN      Taipei
# ...                       ...          ...      ...         ...
# 59471                    2.65         8.52        有  New_Taipei
# 59472                    0.00         0.00        無  New_Taipei
# 59473                    2.64         8.52        有  New_Taipei
# 59474                    0.00         5.40        有  New_Taipei
# 59475                    2.42         8.52        有  New_Taipei
#
# [59476 rows x 33 columns]

# %%
#2. 取出主要用途(main_use)為'住家用'以及都市土地使用分區(use_zoning)為'住'的資料並針對以下欄位analysis_columns做分析並去除na值 (提示:先取完之後再.dropna())
#   (提示:先取完之後再.dropna())
#方法一
#new_df = new_df.loc[(analysis_data.main_use=='住家用')&(analysis_data.use_zoning=='住'),analysis_columns].dropna()

#方法二
new_df = new_df.loc[(new_df["main_use"] == "住家用") & (new_df["use_zoning"] == "住"), analysis_columns]
print(new_df.isna().any())
#刪除缺失直             how = "any"任何有缺失的     axis = 0 橫向
new_df = new_df.dropna(how = "any", axis = 0, subset = analysis_columns)
print(new_df.isna().any())
display(new_df)
# Out:
# city                          False
# towns                         False
# main_use                      False
# use_zoning                    False
# total_price                   False
# building_area_square_meter    False
# main_building_area            False
# tx_dt                         False
# unit_price                     True
# room_number                   False
# hall_number                   False
# health_number                 False
# dtype: bool
# city                          False
# towns                         False
# main_use                      False
# use_zoning                    False
# total_price                   False
# building_area_square_meter    False
# main_building_area            False
# tx_dt                         False
# unit_price                    False
# room_number                   False
# hall_number                   False
# health_number                 False
# dtype: bool
#              city towns main_use use_zoning total_price  \
# 0          Taipei   文山區      住家用          住    36000000
# 1          Taipei   文山區      住家用          住     5580000
# 4          Taipei   文山區      住家用          住    18280000
# 6          Taipei   文山區      住家用          住     8000000
# 7          Taipei   文山區      住家用          住     2200000
# ...           ...   ...      ...        ...         ...
# 48924  New_Taipei   三重區      住家用          住     7280000
# 49200  New_Taipei   三重區      住家用          住     7350000
# 49735  New_Taipei   三重區      住家用          住     6000000
# 49799  New_Taipei   汐止區      住家用          住    11800000
# 51169  New_Taipei   泰山區      住家用          住     9000000
#
#       building_area_square_meter  main_building_area    tx_dt unit_price  \
# 0                         229.91              110.91  1090406     156583
# 1                          37.31               24.58  1090317     149558
# 4                         123.66               98.74  1090328     147825
# 6                         124.25               90.78  1090417      64386
# 7                          30.16               26.15  1090417      72944
# ...                          ...                 ...      ...        ...
# 48924                      84.53               75.34  1090611      86123
# 49200                      84.63               84.63  1090521      86849
# 49735                       67.0               67.00  1090522      89552
# 49799                     124.31               98.54  1090507      94924
# 51169                     193.31               88.80  1090614      46557
#
#       room_number hall_number health_number
# 0               3           2             2
# 1               2           1             1
# 4               3           2             2
# 6               3           1             2
# 7               5           2             2
# ...           ...         ...           ...
# 48924           5           0             5
# 49200           4           0             4
# 49735           1           1             1
# 49799           3           2             2
# 51169           2           2             2
#
# [7802 rows x 12 columns]

# %%
#3. 觀察欄位資料型態，並利用.astype()搭配以下提供的columns_type做欄位型態轉換
print(new_df.info())
new_df = new_df.astype(columns_type)
print(new_df.info())
new_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7802 entries, 0 to 51169
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        7802 non-null   object
#  1   towns                       7802 non-null   object
#  2   main_use                    7802 non-null   object
#  3   use_zoning                  7802 non-null   object
#  4   total_price                 7802 non-null   object
#  5   building_area_square_meter  7802 non-null   object
#  6   main_building_area          7802 non-null   float64
#  7   tx_dt                       7802 non-null   object
#  8   unit_price                  7802 non-null   object
#  9   room_number                 7802 non-null   object
#  10  hall_number                 7802 non-null   object
#  11  health_number               7802 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 792.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7802 entries, 0 to 51169
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        7802 non-null   object
#  1   towns                       7802 non-null   object
#  2   main_use                    7802 non-null   object
#  3   use_zoning                  7802 non-null   object
#  4   total_price                 7802 non-null   int32
#  5   building_area_square_meter  7802 non-null   float64
#  6   main_building_area          7802 non-null   float64
#  7   tx_dt                       7802 non-null   object
#  8   unit_price                  7802 non-null   float64
#  9   room_number                 7802 non-null   int32
#  10  hall_number                 7802 non-null   int32
#  11  health_number               7802 non-null   int32
# dtypes: float64(3), int32(4), object(5)
# memory usage: 670.5+ KB
# None
#      city towns main_use use_zoning  total_price  building_area_square_meter  \
# 0  Taipei   文山區      住家用          住     36000000                      229.91
# 1  Taipei   文山區      住家用          住      5580000                       37.31
# 4  Taipei   文山區      住家用          住     18280000                      123.66
# 6  Taipei   文山區      住家用          住      8000000                      124.25
# 7  Taipei   文山區      住家用          住      2200000                       30.16
#
#    main_building_area    tx_dt  unit_price  room_number  hall_number  \
# 0              110.91  1090406    156583.0            3            2
# 1               24.58  1090317    149558.0            2            1
# 4               98.74  1090328    147825.0            3            2
# 6               90.78  1090417     64386.0            3            1
# 7               26.15  1090417     72944.0            5            2
#
#    health_number
# 0              2
# 1              1
# 4              2
# 6              2
# 7              2

# %%
#4. 做資料切片將
#     新增欄位交易年月日(tx_dt_year)，從交易年月日(tx_dt)萃取出年份
#     1.交易年月日(tx_dt_year)，限制在109年
#     2.建物現況格局-房(room_number)，限制在1到5間
#     3.建物現況格局-廳(hall_number)，限制在1到2廳
#     4.最後運用.reset_index()重新定義索引

#新增交易年欄位
print(new_df["tx_dt"])
#萃取出年分=> 前三位
new_df['tx_dt_year'] = new_df['tx_dt'].apply(lambda x: int(x[:-4]))
print(new_df['tx_dt_year'])

#進行資料篩選
new_df = new_df.loc[(new_df.tx_dt_year>=109)&
                    (new_df.room_number>=1)&
                    (new_df.room_number<=5)&
                    (new_df.hall_number>=1)&
                    (new_df.hall_number<=2)
                   ]
display(new_df)
#重新設定索引
new_df = new_df.reset_index(drop=True)
new_df
# Out:
# 0        1090406
# 1        1090317
# 4        1090328
# 6        1090417
# 7        1090417
#           ...
# 48924    1090611
# 49200    1090521
# 49735    1090522
# 49799    1090507
# 51169    1090614
# Name: tx_dt, Length: 7802, dtype: object
# 0        109
# 1        109
# 4        109
# 6        109
# 7        109
#         ...
# 48924    109
# 49200    109
# 49735    109
# 49799    109
# 51169    109
# Name: tx_dt_year, Length: 7802, dtype: int64
#              city towns main_use use_zoning  total_price  \
# 0          Taipei   文山區      住家用          住     36000000
# 1          Taipei   文山區      住家用          住      5580000
# 4          Taipei   文山區      住家用          住     18280000
# 6          Taipei   文山區      住家用          住      8000000
# 7          Taipei   文山區      住家用          住      2200000
# ...           ...   ...      ...        ...          ...
# 48796  New_Taipei   新店區      住家用          住     10500000
# 48872  New_Taipei   蘆洲區      住家用          住      9200000
# 49735  New_Taipei   三重區      住家用          住      6000000
# 49799  New_Taipei   汐止區      住家用          住     11800000
# 51169  New_Taipei   泰山區      住家用          住      9000000
#
#        building_area_square_meter  main_building_area    tx_dt  unit_price  \
# 0                          229.91              110.91  1090406    156583.0
# 1                           37.31               24.58  1090317    149558.0
# 4                          123.66               98.74  1090328    147825.0
# 6                          124.25               90.78  1090417     64386.0
# 7                           30.16               26.15  1090417     72944.0
# ...                           ...                 ...      ...         ...
# 48796                      112.33               93.18  1090516     93475.0
# 48872                       92.14               86.55  1090529     99848.0
# 49735                       67.00               67.00  1090522     89552.0
# 49799                      124.31               98.54  1090507     94924.0
# 51169                      193.31               88.80  1090614     46557.0
#
#        room_number  hall_number  health_number  tx_dt_year
# 0                3            2              2         109
# 1                2            1              1         109
# 4                3            2              2         109
# 6                3            1              2         109
# 7                5            2              2         109
# ...            ...          ...            ...         ...
# 48796            3            2              2         109
# 48872            3            2              1         109
# 49735            1            1              1         109
# 49799            3            2              2         109
# 51169            2            2              2         109
#
# [6894 rows x 13 columns]
#             city towns main_use use_zoning  total_price  \
# 0         Taipei   文山區      住家用          住     36000000
# 1         Taipei   文山區      住家用          住      5580000
# 2         Taipei   文山區      住家用          住     18280000
# 3         Taipei   文山區      住家用          住      8000000
# 4         Taipei   文山區      住家用          住      2200000
# ...          ...   ...      ...        ...          ...
# 6889  New_Taipei   新店區      住家用          住     10500000
# 6890  New_Taipei   蘆洲區      住家用          住      9200000
# 6891  New_Taipei   三重區      住家用          住      6000000
# 6892  New_Taipei   汐止區      住家用          住     11800000
# 6893  New_Taipei   泰山區      住家用          住      9000000
#
#       building_area_square_meter  main_building_area    tx_dt  unit_price  \
# 0                         229.91              110.91  1090406    156583.0
# 1                          37.31               24.58  1090317    149558.0
# 2                         123.66               98.74  1090328    147825.0
# 3                         124.25               90.78  1090417     64386.0
# 4                          30.16               26.15  1090417     72944.0
# ...                          ...                 ...      ...         ...
# 6889                      112.33               93.18  1090516     93475.0
# 6890                       92.14               86.55  1090529     99848.0
# 6891                       67.00               67.00  1090522     89552.0
# 6892                      124.31               98.54  1090507     94924.0
# 6893                      193.31               88.80  1090614     46557.0
#
#       room_number  hall_number  health_number  tx_dt_year
# 0               3            2              2         109
# 1               2            1              1         109
# 2               3            2              2         109
# 3               3            1              2         109
# 4               5            2              2         109
# ...           ...          ...            ...         ...
# 6889            3            2              2         109
# 6890            3            2              1         109
# 6891            1            1              1         109
# 6892            3            2              2         109
# 6893            2            2              2         109
#
# [6894 rows x 13 columns]

# %% [markdown]
# # 3. 建立自定義特徵加入分析

# %% [markdown]
# 以台灣來說大家都是以坪為單位計算使用面積，應該是不會問說你家有幾平方公尺吧?，但是偏偏資料中沒有以坪為單位計算，所以接下來請各位幫忙產生新的欄位以坪為單位計算面積，轉換公式我也幫你找好了，在下面的定義。<br>
# 定義 : 1平方公尺相當於0.3025坪 <br>
# 建立新特徵
# 1. 建物移轉總面積坪(building_area_square_feet) : 建物移轉總面積平方公尺\*0.3025
# 2. 主建物面積坪(main_building_area_square_feet) : 主建物面積\*0.3025
# 3. 單價元坪(unit_price_square_feet) : 單價元平方公尺/0.3025

# %% [markdown]
# 可以利用.describe()做一下資料觀察，是否有奇怪的資料?<br>
# 如果有請將資料移除，並說明為什麼移除此資料?<br>
# 移除後再用.describe()觀察是否還有奇怪的資料?

# %%
# 建立新特徵
# 1. 建物移轉總面積坪(building_area_square_feet) : 建物移轉總面積平方公尺*0.3025
new_df['building_area_square_feet'] = new_df.building_area_square_meter*0.3025

# 2. 主建物面積坪(main_building_area_square_feet) : 主建物面積*0.3025
new_df['main_building_area_square_feet'] = new_df.main_building_area*0.3025

# 3. 單價元坪(unit_price_square_feet) : 單價元平方公尺/0.3025
new_df['unit_price_square_feet'] = new_df.unit_price/0.3025

new_df
# Out:
#             city towns main_use use_zoning  total_price  \
# 0         Taipei   文山區      住家用          住     36000000
# 1         Taipei   文山區      住家用          住      5580000
# 2         Taipei   文山區      住家用          住     18280000
# 3         Taipei   文山區      住家用          住      8000000
# 4         Taipei   文山區      住家用          住      2200000
# ...          ...   ...      ...        ...          ...
# 6889  New_Taipei   新店區      住家用          住     10500000
# 6890  New_Taipei   蘆洲區      住家用          住      9200000
# 6891  New_Taipei   三重區      住家用          住      6000000
# 6892  New_Taipei   汐止區      住家用          住     11800000
# 6893  New_Taipei   泰山區      住家用          住      9000000
#
#       building_area_square_meter  main_building_area    tx_dt  unit_price  \
# 0                         229.91              110.91  1090406    156583.0
# 1                          37.31               24.58  1090317    149558.0
# 2                         123.66               98.74  1090328    147825.0
# 3                         124.25               90.78  1090417     64386.0
# 4                          30.16               26.15  1090417     72944.0
# ...                          ...                 ...      ...         ...
# 6889                      112.33               93.18  1090516     93475.0
# 6890                       92.14               86.55  1090529     99848.0
# 6891                       67.00               67.00  1090522     89552.0
# 6892                      124.31               98.54  1090507     94924.0
# 6893                      193.31               88.80  1090614     46557.0
#
#       room_number  hall_number  health_number  tx_dt_year  \
# 0               3            2              2         109
# 1               2            1              1         109
# 2               3            2              2         109
# 3               3            1              2         109
# 4               5            2              2         109
# ...           ...          ...            ...         ...
# 6889            3            2              2         109
# 6890            3            2              1         109
# 6891            1            1              1         109
# 6892            3            2              2         109
# 6893            2            2              2         109
#
#       building_area_square_feet  main_building_area_square_feet  \
# 0                     69.547775                       33.550275
# 1                     11.286275                        7.435450
# 2                     37.407150                       29.868850
# 3                     37.585625                       27.460950
# 4                      9.123400                        7.910375
# ...                         ...                             ...
# 6889                  33.979825                       28.186950
# 6890                  27.872350                       26.181375
# 6891                  20.267500                       20.267500
# 6892                  37.603775                       29.808350
# 6893                  58.476275                       26.862000
#
#       unit_price_square_feet
# 0              517629.752066
# 1              494406.611570
# 2              488677.685950
# 3              212846.280992
# 4              241137.190083
# ...                      ...
# 6889           309008.264463
# 6890           330076.033058
# 6891           296039.669421
# 6892           313798.347107
# 6893           153907.438017
#
# [6894 rows x 16 columns]

# %%
# 可以利用.describe()做一下資料觀察，是否有奇怪的資料?
new_df.describe()
# 如果有請將資料移除，並說明為什麼移除此資料?
# 觀察到有總價 total_price最小值為 0 
# 還有主建物面積main_building_area最小為0的，進一步將其拿掉
# Out:
#         total_price  building_area_square_meter  main_building_area  \
# count  6.894000e+03                 6894.000000         6894.000000
# mean   1.138712e+07                  121.712089           82.086667
# std    1.159445e+07                   62.871712           37.363166
# min    0.000000e+00                    0.970000            0.000000
# 25%    5.580000e+06                   82.965000           60.682500
# 50%    8.550000e+06                  109.390000           78.990000
# 75%    1.329500e+07                  147.517500           95.797500
# max    2.250000e+08                 1444.950000          335.760000
#
#           unit_price  room_number  hall_number  health_number  tx_dt_year  \
# count    6894.000000  6894.000000  6894.000000    6894.000000      6894.0
# mean    94364.671163     2.850885     1.793299       1.733536       109.0
# std     58317.311227     0.898498     0.404969       0.681085         0.0
# min         0.000000     1.000000     1.000000       0.000000       109.0
# 25%     53532.250000     2.000000     2.000000       1.000000       109.0
# 50%     79610.000000     3.000000     2.000000       2.000000       109.0
# 75%    118728.250000     3.000000     2.000000       2.000000       109.0
# max    610104.000000     5.000000     2.000000       6.000000       109.0
#
#        building_area_square_feet  main_building_area_square_feet  \
# count                6894.000000                     6894.000000
# mean                   36.817907                       24.831217
# std                    19.018693                       11.302358
# min                     0.293425                        0.000000
# 25%                    25.096912                       18.356456
# 50%                    33.090475                       23.894475
# 75%                    44.624044                       28.978744
# max                   437.097375                      101.567400
#
#        unit_price_square_feet
# count            6.894000e+03
# mean             3.119493e+05
# std              1.927845e+05
# min              0.000000e+00
# 25%              1.769661e+05
# 50%              2.631736e+05
# 75%              3.924901e+05
# max              2.016873e+06

# %%
# 移除後再用.describe()觀察是否還有奇怪的資料?
#方法一 只保留total price 不等於0且main_build_area也不等於0的數據
new_df = new_df.loc[(new_df.total_price !=0) & (new_df.main_building_area !=0)]
new_df.describe()

#方法二:移除掉所有一坪單價等於0的數據
# import numpy as np 
# new_df = new_df.drop(np.where(new_df["unit_price_square_feet"] == 0)[0])
# Out:
#         total_price  building_area_square_meter  main_building_area  \
# count  6.854000e+03                 6854.000000         6854.000000
# mean   1.141669e+07                  121.768404           82.565725
# std    1.161669e+07                   62.849105           36.940424
# min    4.100000e+05                    7.440000            7.440000
# 25%    5.600000e+06                   83.012500           61.062500
# 50%    8.600000e+06                  109.405000           79.110000
# 75%    1.330000e+07                  147.445000           95.970000
# max    2.250000e+08                 1444.950000          335.760000
#
#           unit_price  room_number  hall_number  health_number  tx_dt_year  \
# count    6854.000000  6854.000000  6854.000000    6854.000000      6854.0
# mean    94548.453020     2.849869     1.793114       1.733149       109.0
# std     58374.690321     0.898343     0.405103       0.680869         0.0
# min      3239.000000     1.000000     1.000000       0.000000       109.0
# 25%     53597.250000     2.000000     2.000000       1.000000       109.0
# 50%     79742.500000     3.000000     2.000000       2.000000       109.0
# 75%    118880.000000     3.000000     2.000000       2.000000       109.0
# max    610104.000000     5.000000     2.000000       6.000000       109.0
#
#        building_area_square_feet  main_building_area_square_feet  \
# count                6854.000000                     6854.000000
# mean                   36.834942                       24.976132
# std                    19.011854                       11.174478
# min                     2.250600                        2.250600
# 25%                    25.111281                       18.471406
# 50%                    33.095012                       23.930775
# 75%                    44.602112                       29.030925
# max                   437.097375                      101.567400
#
#        unit_price_square_feet
# count            6.854000e+03
# mean             3.125569e+05
# std              1.929742e+05
# min              1.070744e+04
# 25%              1.771810e+05
# 50%              2.636116e+05
# 75%              3.929917e+05
# max              2.016873e+06

# %% [markdown]
# # 4. 找出台北市時價登入總價高度相關的變數

# %% [markdown]
# 阿宏我是台北人他想找出影響台北市總價、單價元坪的因子<br>
# 相關係數0.3以下為低相關，0.3\~0.7為中等相關，0.7以上為高度相關<br>
# 1. 資料切片切出city欄位為台北市的資料，並找出時價登入總價(total_price)高度相關的變數
# 2. 資料切片切出city欄位為台北市的資料，找出單價元坪(unit_price_square_feet)高度相關的變數

# %%
# 阿宏我是台北人他想找出影響台北市總價、單價元坪的因子
# 1. 資料切片切出city欄位為台北市的資料，並找出時價登入總價(total_price)高度相關的變數
# 建物移轉總面積平方公尺(building_area_square_meter)、
# 主建物面積(main_building_area)、建物移轉總面積坪、主建物面積坪
# 2. 資料切片切出city欄位為台北市的資料，找出單價元坪(unit_price_square_feet)高度相關的變數
# 單價元平方公尺
corr_data = new_df.loc[new_df.city =='Taipei'].corr()[ ['total_price','unit_price_square_feet'] ]
corr_data
# Out:
#                                 total_price  unit_price_square_feet
# total_price                        1.000000                0.581290
# building_area_square_meter         0.864627                0.218185
# main_building_area                 0.710515                0.112488
# unit_price                         0.581290                1.000000
# room_number                        0.326441               -0.100062
# hall_number                        0.270787                0.004883
# health_number                      0.598832                0.128217
# tx_dt_year                              NaN                     NaN
# building_area_square_feet          0.864627                0.218185
# main_building_area_square_feet     0.710515                0.112488
# unit_price_square_feet             0.581290                1.000000

# %%
#找出與時價登入總價(total_price)高度相關的變數
total_price_high_relevant = abs(corr_data["total_price"]) >= 0.7
display(total_price_high_relevant[total_price_high_relevant == True].index)

#找出單價元平(unit_price_square_feet)高度相關的變數
unit_price_square_feet_high_relevant = abs(corr_data["unit_price_square_feet"]) >= 0.7
print(unit_price_square_feet_high_relevant[unit_price_square_feet_high_relevant == True].index)
# Out:
# Index(['total_price', 'building_area_square_meter', 'main_building_area',
#        'building_area_square_feet', 'main_building_area_square_feet'],
#       dtype='object')
# Index(['unit_price', 'unit_price_square_feet'], dtype='object')

# %% [markdown]
# # 5. 資料視覺化並解釋

# %% [markdown]
# 我想要以視覺化的方式來看房價資料，並且請各位資料科學家解釋圖表給阿宏我知道
# 1. 以城市(city)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區
# 2. 進一步對台北市的資料做圖，以建物現況格局-房(room_number)為x軸，以總價元(total_price)為y軸畫出boxplot，並找出總價元(total_price)中位數最高的房間數。hint:資料切片找出city欄位為台北市的資料，再進一步畫圖
# 3. 對台北市的資料做圖，先將地區(twons)做編碼在進行，再以地區(twon)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區。hint:運用LabelEncoder()對地區(twons)做編碼，運用.inverse_transform()反查編碼的地區

# %%
#1. 以城市(city)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區
#台北市
new_df.boxplot(column = ['unit_price_square_feet'], by='city', figsize=(16,6))
# Out:
# <AxesSubplot:title={'center':'unit_price_square_feet'}, xlabel='city'>

# %%
#2. 進一步對台北市的資料做圖，以建物現況格局-房(room_number)為x軸，以總價元(total_price)為y軸畫出boxplot，並找出總價元(total_price)中位數最高的房間數。hint:資料切片找出city欄位為台北市的資料，再進一步畫圖
#5
#方法一
new_df[new_df["city"] == 'Taipei'].boxplot(column = ['total_price'],by = 'room_number',figsize=(18,8))

#方法二
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize = (18,8))
sns.boxplot(data = new_df[new_df["city"] == "Taipei"], x = "room_number", y = "total_price");

# %%
#3. 對台北市的資料做圖，先將地區(twons)做編碼在進行，再以地區(twon)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區。
# hint:運用LabelEncoder()對地區(twons)做編碼，運用.inverse_transform()反查編碼的地區
#大安區
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
new_df['town_label_encoding'] = le.fit_transform(new_df['towns'])
new_df['town_label_encoding']
# Out:
# 0       39
# 1       39
# 2       39
# 3       39
# 4       39
#         ..
# 6889    40
# 6890    74
# 6891     3
# 6892    56
# 6893    58
# Name: town_label_encoding, Length: 6854, dtype: int32

# %%
#方法一
new_df.loc[new_df.city=='Taipei'].boxplot(column = ['unit_price_square_feet'], by='town_label_encoding',figsize=(18,8))

#方法二
fig = plt.figure(figsize = (18,8))
sns.boxplot(data = new_df[new_df["city"] == "Taipei"],x = "town_label_encoding", y = "unit_price_square_feet")
# Out:
# <AxesSubplot:xlabel='town_label_encoding', ylabel='unit_price_square_feet'>

# %%
le.inverse_transform([26])
# Out:
# array(['大安區'], dtype=object)
