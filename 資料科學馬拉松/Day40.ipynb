# %% [markdown]
# ## 今天的範例，帶著大家一起發現具有特徵的資料

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline
# Out:
# 0.22.1

# %% [markdown]
# ## 產生一組資料集

# %%
#用字典產生一組資料
data={'sex': ['Male','Male','Male','Male','Male','Female','Female','Female','Female','Female','Male','Male','Male','Male','Male','Female','Female','Female','Female','Female'],
      'insomnia':['Y','N','N','N','N','N','Y','Y','Y','N','Y','N','N','N','N','N','Y','Y','Y','N'],
     'age':[23,40,5,30,1,40,16,27,43,8,23,39,5,29,1,42,13,29,41,10],
     'height':[180,170,100,176,70,160,170,166,155,35,170,168,101,175,72,163,169,163,151,40],
     'weight':[100,68,20,70,10,45,50,58,58,17,101,65,22,79,12,40,53,52,56,14]}
#轉成 dataframe格式 
data=pd.DataFrame(data)
display(data)

print(data.info())
# Out:
#        sex insomnia  age  height  weight
# 0     Male        Y   23     180     100
# 1     Male        N   40     170      68
# 2     Male        N    5     100      20
# 3     Male        N   30     176      70
# 4     Male        N    1      70      10
# 5   Female        N   40     160      45
# 6   Female        Y   16     170      50
# 7   Female        Y   27     166      58
# 8   Female        Y   43     155      58
# 9   Female        N    8      35      17
# 10    Male        Y   23     170     101
# 11    Male        N   39     168      65
# 12    Male        N    5     101      22
# 13    Male        N   29     175      79
# 14    Male        N    1      72      12
# 15  Female        N   42     163      40
# 16  Female        Y   13     169      53
# 17  Female        Y   29     163      52
# 18  Female        Y   41     151      56
# 19  Female        N   10      40      14
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e46c88c068c2> in <module>
#       9 display(data)
#      10
# ---> 11 print(data.info())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2495                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2496                     size_qualifier = "+"
# -> 2497             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2498             lines.append(f"memory usage: {_sizeof_fmt(mem_usage, size_qualifier)}\n")
#    2499         fmt.buffer_put_lines(buf, lines)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2588         )
#    2589         if index:
# -> 2590             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2591                 result
#    2592             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# --> 305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
#     307                 data = SingleBlockManager(data, index, fastpath=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# ## 我們要找那些資料點和失眠相關，具有特徵的變異性?

# %% [markdown]
# ### 具有變異性的資料

# %% [markdown]
# ## 連續型資料

# %%
# 計算變異數的方法
print("男孩年齡變異數=",statistics.variance(data['age']))
print("男孩年齡變異數=",np.var(data['age'],ddof=1))
# Out:
# 男孩年齡變異數= 221.77631578947367
# 男孩年齡變異數= 221.77631578947367

# %%
#最後，畫圖看分布
plt.hist(data['age'],alpha=.4,bins=40)
plt.title('boy,skewness={0},kurtosis={1}'.format(round(stats.skew(data['age']),2),round(stats.kurtosis(data['age']),2)))
plt.axvline(x=np.mean(data['age']))
plt.show()

# %%
## 可由變異數等分散變量與圖形，判斷資料是否有變異性，以這個例子，年紀是具有變異性的特徵。

# %% [markdown]
# ## 離散型資料

# %%
data[['insomnia','sex']].groupby('sex').count()
# Out:
#         insomnia
# sex
# Female        10
# Male          10

# %%
data[data['insomnia']=='Y'].groupby('sex').count()
#當離散型資料不集中於某一個欄位，如此資料集，則稱為具有變異性
# Out:
#         insomnia  age  height  weight
# sex
# Female         6    6       6       6
# Male           2    2       2       2

# %% [markdown]
# ### 衍生資料的方法:
# 把原始資料做一些轉換，萃取出和目標變數相關的特徵，大致上可以分成以下幾種類型， 稱作 ICR 步驟。
# * 指示器變量(Indicator)
# * 資料組合(Combination)
# * 資料重新定義(Reshape)

# %% [markdown]
# ### 指示器變量(Indicator)
# 這邊我們運用 Weight 這個變數來當例子，進行示範
# ![image.png](attachment:image.png)

# %%
# 運用 apply function  做變數轉換
data['weight_new']=data['weight'].apply((lambda x: 1 if x >=100 else 0))

display(data.head(5))
# Out:
#     sex insomnia  age  height  weight  weight_new
# 0  Male        Y   23     180     100           1
# 1  Male        N   40     170      68           0
# 2  Male        N    5     100      20           0
# 3  Male        N   30     176      70           0
# 4  Male        N    1      70      10           0

# %% [markdown]
# ### 資料組合(Combination)
# ![image.png](attachment:image.png)

# %%
# 運用四則運算，來做計算
data['BMI']=round(data['weight']/data['height']/data['height']*100*100,2)

display(data.head(5))
# Out:
#     sex insomnia  age  height  weight  weight_new    BMI
# 0  Male        Y   23     180     100           1  30.86
# 1  Male        N   40     170      68           0  23.53
# 2  Male        N    5     100      20           0  20.00
# 3  Male        N   30     176      70           0  22.60
# 4  Male        N    1      70      10           0  20.41

# %% [markdown]
# ###  資料重新定義(Reshape)

# %% [markdown]
# 1. 資料收集長度調整:
# 預測地下水水位，時雨量比10分鐘及時雨量還好，沒有時間遞延問題，透過調整增強數據所能表達的信息。
# 2. 數值到分類的映射:
# 可以將年齡，分成兒童、青少年、青年與青壯年各個年級的資料。
# 3. 合併稀疏分類:
# 發現年齡中，某一個年齡層人數偏少，可以做合併的動作。
# 4. 表達類別型資料的距離:
# 重新定義類別資料距離: 比如年齡資料，兒童、青少年與成年可轉換為1,2,3。
# 5. 創造虛擬資料:
# 這取決與機器學習算法的實現，將類別特徵轉換到虛擬變量中去。

# %%
## 數值到分類的映射
# 運用 apply function  做變數轉換
def age_map(x): 
    if(x<=12):
        return('child')
    else: 
        if(x<=18):
            return('teens')
        else:
            return('adult')
    
data['age_category']=data['age'].apply(age_map)

display(data)
# Out:
#        sex insomnia  age  height  weight  weight_new     BMI age_category
# 0     Male        Y   23     180     100           1   30.86        adult
# 1     Male        N   40     170      68           0   23.53        adult
# 2     Male        N    5     100      20           0   20.00        child
# 3     Male        N   30     176      70           0   22.60        adult
# 4     Male        N    1      70      10           0   20.41        child
# 5   Female        N   40     160      45           0   17.58        adult
# 6   Female        Y   16     170      50           0   17.30        teens
# 7   Female        Y   27     166      58           0   21.05        adult
# 8   Female        Y   43     155      58           0   24.14        adult
# 9   Female        N    8      35      17           0  138.78        child
# 10    Male        Y   23     170     101           1   34.95        adult
# 11    Male        N   39     168      65           0   23.03        adult
# 12    Male        N    5     101      22           0   21.57        child
# 13    Male        N   29     175      79           0   25.80        adult
# 14    Male        N    1      72      12           0   23.15        child
# 15  Female        N   42     163      40           0   15.06        adult
# 16  Female        Y   13     169      53           0   18.56        teens
# 17  Female        Y   29     163      52           0   19.57        adult
# 18  Female        Y   41     151      56           0   24.56        adult
# 19  Female        N   10      40      14           0   87.50        child

# %%
## 合併稀疏分類
contTable = pd.crosstab(data['age_category'], data['insomnia'])
contTable
# 有兩個零的存在，太過稀疏，有時候會將 age_category中的 child  和 teens 合併，但如果最後應用端要把 age 分成三種類型的話，就不會合併
# Out:
# insomnia      N  Y
# age_category
# adult         6  6
# child         6  0
# teens         0  2

# %%
##現在假設要合併的話可以怎麼做?
#產生一個新的 mapping function 然後做調整
def age_map_2(x): 
    if(x<=18):
        return('child_teens')
    else:
        return('adult')
    
data['age_category']=data['age'].apply(age_map_2)

display(data)
# Out:
#        sex insomnia  age  height  weight  weight_new     BMI age_category
# 0     Male        Y   23     180     100           1   30.86        adult
# 1     Male        N   40     170      68           0   23.53        adult
# 2     Male        N    5     100      20           0   20.00  child_teens
# 3     Male        N   30     176      70           0   22.60        adult
# 4     Male        N    1      70      10           0   20.41  child_teens
# 5   Female        N   40     160      45           0   17.58        adult
# 6   Female        Y   16     170      50           0   17.30  child_teens
# 7   Female        Y   27     166      58           0   21.05        adult
# 8   Female        Y   43     155      58           0   24.14        adult
# 9   Female        N    8      35      17           0  138.78  child_teens
# 10    Male        Y   23     170     101           1   34.95        adult
# 11    Male        N   39     168      65           0   23.03        adult
# 12    Male        N    5     101      22           0   21.57  child_teens
# 13    Male        N   29     175      79           0   25.80        adult
# 14    Male        N    1      72      12           0   23.15  child_teens
# 15  Female        N   42     163      40           0   15.06        adult
# 16  Female        Y   13     169      53           0   18.56  child_teens
# 17  Female        Y   29     163      52           0   19.57        adult
# 18  Female        Y   41     151      56           0   24.56        adult
# 19  Female        N   10      40      14           0   87.50  child_teens

# %%
#定義類別資料距離
data['age_category']=data['age'].apply(age_map)
size_mapping = {'child':1, 'teens':2, 'adult':3}
data['age_conti'] = data['age_category'].map(size_mapping)
display(data)
# Out:
#        sex insomnia  age  height  weight  weight_new     BMI age_category  \
# 0     Male        Y   23     180     100           1   30.86        adult
# 1     Male        N   40     170      68           0   23.53        adult
# 2     Male        N    5     100      20           0   20.00        child
# 3     Male        N   30     176      70           0   22.60        adult
# 4     Male        N    1      70      10           0   20.41        child
# 5   Female        N   40     160      45           0   17.58        adult
# 6   Female        Y   16     170      50           0   17.30        teens
# 7   Female        Y   27     166      58           0   21.05        adult
# 8   Female        Y   43     155      58           0   24.14        adult
# 9   Female        N    8      35      17           0  138.78        child
# 10    Male        Y   23     170     101           1   34.95        adult
# 11    Male        N   39     168      65           0   23.03        adult
# 12    Male        N    5     101      22           0   21.57        child
# 13    Male        N   29     175      79           0   25.80        adult
# 14    Male        N    1      72      12           0   23.15        child
# 15  Female        N   42     163      40           0   15.06        adult
# 16  Female        Y   13     169      53           0   18.56        teens
# 17  Female        Y   29     163      52           0   19.57        adult
# 18  Female        Y   41     151      56           0   24.56        adult
# 19  Female        N   10      40      14           0   87.50        child
#
#     age_conti
# 0           3
# 1           3
# 2           1
# 3           3
# 4           1
# 5           3
# 6           2
# 7           3
# 8           3
# 9           1
# 10          3
# 11          3
# 12          1
# 13          3
# 14          1
# 15          3
# 16          2
# 17          3
# 18          3
# 19          1

# %%
# 先將需要的欄取出
b = data[['age_category']]
#columns 代表取出欄位,透過 prefix 來調整欄位名稱
dummy=pd.get_dummies(b, columns=['age_category'], prefix=['age'])
#資料合併
data=pd.concat([data,dummy],axis=1)
display(data)
# Out:
#        sex insomnia  age  height  weight  weight_new     BMI age_category  \
# 0     Male        Y   23     180     100           1   30.86        adult
# 1     Male        N   40     170      68           0   23.53        adult
# 2     Male        N    5     100      20           0   20.00        child
# 3     Male        N   30     176      70           0   22.60        adult
# 4     Male        N    1      70      10           0   20.41        child
# 5   Female        N   40     160      45           0   17.58        adult
# 6   Female        Y   16     170      50           0   17.30        teens
# 7   Female        Y   27     166      58           0   21.05        adult
# 8   Female        Y   43     155      58           0   24.14        adult
# 9   Female        N    8      35      17           0  138.78        child
# 10    Male        Y   23     170     101           1   34.95        adult
# 11    Male        N   39     168      65           0   23.03        adult
# 12    Male        N    5     101      22           0   21.57        child
# 13    Male        N   29     175      79           0   25.80        adult
# 14    Male        N    1      72      12           0   23.15        child
# 15  Female        N   42     163      40           0   15.06        adult
# 16  Female        Y   13     169      53           0   18.56        teens
# 17  Female        Y   29     163      52           0   19.57        adult
# 18  Female        Y   41     151      56           0   24.56        adult
# 19  Female        N   10      40      14           0   87.50        child
#
#     age_conti  age_adult  age_child  age_teens
# 0           3          1          0          0
# 1           3          1          0          0
# 2           1          0          1          0
# 3           3          1          0          0
# 4           1          0          1          0
# 5           3          1          0          0
# 6           2          0          0          1
# 7           3          1          0          0
# 8           3          1          0          0
# 9           1          0          1          0
# 10          3          1          0          0
# 11          3          1          0          0
# 12          1          0          1          0
# 13          3          1          0          0
# 14          1          0          1          0
# 15          3          1          0          0
# 16          2          0          0          1
# 17          3          1          0          0
# 18          3          1          0          0
# 19          1          0          1          0
